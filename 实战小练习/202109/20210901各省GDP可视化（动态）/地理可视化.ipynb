# %%
import pandas as pd
from pandas.core.reshape.concat import concat
import pathlib2 as pl2
from pyecharts import options as opts
from pyecharts.charts import Map, Timeline
import numpy as np


df = pd.read_csv('./data_combine.csv',encoding='utf-8')
df_area = df.iloc[:,1:3]
df_year = df.iloc[:,[-1]]
df_new = concat([df_area,df_year], axis = 1)
df_end = df_new.groupby(by=['year'])


tl = Timeline()
for i in range(2016, 2020):
    map0 = (
        Map()
        .add("", [list(z) for z in zip([provinve[:2] for provinve in np.array(df_end.get_group(i).iloc[1:,[0]]).flatten().tolist()],np.array(df_end.get_group(i).iloc[1:,[1]]).astype('int').flatten().tolist())], "china")  # 以列表形式存放数据
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Map-{}年某些数据".format(i)),
            visualmap_opts=opts.VisualMapOpts(max_=85000),
        )
    )
    tl.add(map0, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="46377466c8b04f7e9d99e1a7ba49fe8e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_46377466c8b04f7e9d99e1a7ba49fe8e = echarts.init(
#                     document.getElementById('46377466c8b04f7e9d99e1a7ba49fe8e'), 'white', {renderer: 'canvas'});
#                 var option_46377466c8b04f7e9d99e1a7ba49fe8e = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "map",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "mapType": "china",
#                 "data": [
#                     {
#                         "name": "\u5929\u6d25",
#                         "value": 14055
#                     },
#                     {
#                         "name": "\u6cb3\u5317",
#                         "value": 34978
#                     },
#                     {
#                         "name": "\u5c71\u897f",
#                         "value": 16961
#                     },
#                     {
#                         "name": "\u5185\u8499",
#                         "value": 17212
#                     },
#                     {
#                         "name": "\u8fbd\u5b81",
#                         "value": 24855
#                     },
#                     {
#                         "name": "\u5409\u6797",
#                         "value": 11726
#                     },
#                     {
#                         "name": "\u9ed1\u9f99",
#                         "value": 13544
#                     },
#                     {
#                         "name": "\u4e0a\u6d77",
#                         "value": 37987
#                     },
#                     {
#                         "name": "\u6c5f\u82cf",
#                         "value": 98656
#                     },
#                     {
#                         "name": "\u6d59\u6c5f",
#                         "value": 62462
#                     },
#                     {
#                         "name": "\u5b89\u5fbd",
#                         "value": 36845
#                     },
#                     {
#                         "name": "\u798f\u5efa",
#                         "value": 42326
#                     },
#                     {
#                         "name": "\u6c5f\u897f",
#                         "value": 24667
#                     },
#                     {
#                         "name": "\u5c71\u4e1c",
#                         "value": 70540
#                     },
#                     {
#                         "name": "\u6cb3\u5357",
#                         "value": 53717
#                     },
#                     {
#                         "name": "\u6e56\u5317",
#                         "value": 45429
#                     },
#                     {
#                         "name": "\u6e56\u5357",
#                         "value": 39894
#                     },
#                     {
#                         "name": "\u5e7f\u4e1c",
#                         "value": 107986
#                     },
#                     {
#                         "name": "\u5e7f\u897f",
#                         "value": 21237
#                     },
#                     {
#                         "name": "\u6d77\u5357",
#                         "value": 5330
#                     },
#                     {
#                         "name": "\u91cd\u5e86",
#                         "value": 23605
#                     },
#                     {
#                         "name": "\u56db\u5ddd",
#                         "value": 46363
#                     },
#                     {
#                         "name": "\u8d35\u5dde",
#                         "value": 16769
#                     },
#                     {
#                         "name": "\u4e91\u5357",
#                         "value": 23223
#                     },
#                     {
#                         "name": "\u897f\u85cf",
#                         "value": 1697
#                     },
#                     {
#                         "name": "\u9655\u897f",
#                         "value": 25793
#                     },
#                     {
#                         "name": "\u7518\u8083",
#                         "value": 8718
#                     },
#                     {
#                         "name": "\u9752\u6d77",
#                         "value": 2941
#                     },
#                     {
#                         "name": "\u5b81\u590f",
#                         "value": 3748
#                     }
#                 ],
#                 "roam": true,
#                 "aspectScale": 0.75,
#                 "nameProperty": "name",
#                 "selectedMode": false,
#                 "zoom": 1,
#                 "mapValueCalculation": "sum",
#                 "showLegendSymbol": true,
#                 "emphasis": {}
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "visualMap": {
#             "show": true,
#             "type": "continuous",
#             "min": 0,
#             "max": 85000,
#             "inRange": {
#                 "color": [
#                     "#50a3ba",
#                     "#eac763",
#                     "#d94e5d"
#                 ]
#             },
#             "calculable": true,
#             "inverse": false,
#             "splitNumber": 5,
#             "orient": "vertical",
#             "showLabel": true,
#             "itemWidth": 20,
#             "itemHeight": 140,
#             "borderWidth": 0
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         ""
#                     ],
#                     "selected": {
#                         "": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "map",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     },
#                     "mapType": "china",
#                     "data": [
#                         {
#                             "name": "\u5929\u6d25",
#                             "value": 11477
#                         },
#                         {
#                             "name": "\u6cb3\u5317",
#                             "value": 28474
#                         },
#                         {
#                             "name": "\u5c71\u897f",
#                             "value": 11946
#                         },
#                         {
#                             "name": "\u5185\u8499",
#                             "value": 13789
#                         },
#                         {
#                             "name": "\u8fbd\u5b81",
#                             "value": 20392
#                         },
#                         {
#                             "name": "\u5409\u6797",
#                             "value": 10427
#                         },
#                         {
#                             "name": "\u9ed1\u9f99",
#                             "value": 11895
#                         },
#                         {
#                             "name": "\u4e0a\u6d77",
